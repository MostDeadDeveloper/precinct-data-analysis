# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager


from pyvirtualdisplay import Display

# %%
#Display in order to avoid CloudFare bot detection
display = Display(visible=0, size=(800, 800))  
display.start()

options = webdriver.ChromeOptions()
options.add_argument('--no-sandbox')
options.add_argument('start-maximized')
options.add_argument('enable-automation')
options.add_argument('--disable-infobars')
options.add_argument('--disable-dev-shm-usage')
options.add_argument('--disable-browser-side-navigation')
options.add_argument("--remote-debugging-port=9222")
# options.add_argument("--headless")
options.add_argument('--disable-gpu')
options.add_argument("--log-level=3")
driver = webdriver.Chrome(ChromeDriverManager().install(), chrome_options=options)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 92.0.4515
# Get LATEST chromedriver version for 92.0.4515 google-chrome
# There is no [linux64] chromedriver for browser 92.0.4515 in cache
# Trying to download new driver from https://chromedriver.storage.googleapis.com/92.0.4515.107/chromedriver_linux64.zip
# Driver has been saved in cache [/home/randomuser/.wdm/drivers/chromedriver/linux64/92.0.4515.107]
# /tmp/ipykernel_159260/3117613463.py:16: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(ChromeDriverManager().install(), chrome_options=options)

# %%
driver.get('https://2022electionresults.comelec.gov.ph')

# %%
print(driver.page_source)
# Out:
# <html xmlns:th="http://www.thymeleaf.org" xmlns="http://www.w3.org/1999/xhtml" ng-app="psPhl" class="ng-scope"><head><style type="text/css">@charset "UTF-8";[ng\:cloak],[ng-cloak],[data-ng-cloak],[x-ng-cloak],.ng-cloak,.x-ng-cloak,.ng-hide:not(.ng-hide-animate){display:none !important;}ng\:form{display:block;}.ng-animate-shim{visibility:hidden;}.ng-anchor{position:absolute;}</style>
# 	<base href="./">
# 	<meta name="viewport" content="width=device-width, initial-scale=1">
# 	<meta http-equiv="Content-Type" content="text/html; charset=UTF-8">
# 	<!-- meta name="description" th:content=""/-->
# 	<!-- meta name="keywords" th:content=""/-->
# 	<!-- meta name="author" th:content=""/-->
# 	<title th:utext="#{public.site.page.title}" ng-bind-html="'page.title' | translate" class="ng-binding">2022 NLE</title>
#
# 	<style type="text/css">
# 		[ng\:cloak], [ng-cloak], [data-ng-cloak], [x-ng-cloak], .ng-cloak, .x-ng-cloak {
# 			display: none !important;
# 		}
# 	</style>
#
# 	<link rel="icon" type="image/png" href="styles/images/icon.ico" sizes="16x16">
# 	<link rel="stylesheet" type="text/css" href="styles/jquery-ui.min.css">
# 	<link rel="stylesheet" type="text/css" href="styles/bootstrap.min.css">
# 	<link rel="stylesheet" type="text/css" href="styles/baseTemplate.css">
# 	<link rel="stylesheet" type="text/css" href="styles/bootstrap-column-height.css">
# 	<link rel="stylesheet" type="text/css" href="styles/fonts/fonts.css">
#
# 	<script src="scripts/libraries/jquery.min.js"></script>
# 	<script src="scripts/libraries/bootstrap.min.js"></script>
# 	<script src="scripts/libraries/d3.v3.min.js" charset="utf-8"></script>
# 	<script src="scripts/libraries/topojson.v1.min.js" charset="utf-8" xml:space="preserve"></script>
# 	<script src="scripts/libraries/moment.js"></script>
# 	<script src="scripts/libraries/angular.min.js"></script>
# 	<script src="i18n/messages.js"></script>
# 	<script src="scripts/libraries/angular-translate.js"></script>
# 	<script src="scripts/libraries/angular-sanitize.js"></script>
# 	<script src="scripts/libraries/angular-ui-router.min.js"></script>
#
# 	<script src="scripts/app/dashboard/dashboardTableCtrlr.js"></script>
# 	<script src="scripts/app/dashboard/dashboardCtrlr.js"></script>
#
# 	<script src="scripts/app/results/cocCtrlr.js"></script>
# 	<script src="scripts/app/results/erCtrlr.js"></script>
# 	<script src="scripts/app/results/totCtrlr.js"></script>
# 	<script src="scripts/app/results/resultsCtrlr.js"></script>
# 	<script src="scripts/app/statistics/statisticsCtrlr.js"></script>
# 	<script src="scripts/app/contests/contestsCtrlr.js"></script>
# 	<script src="scripts/app/navigation/navigationFilterCtrlr.js"></script>
# 	<script src="scripts/app/map/mapCtrlr.js"></script>
# 	<script src="scripts/app/search/searchCtrlr.js"></script>
# 	<script src="scripts/app/psPhlCtrlr.js"></script>
# 	<script src="scripts/app/smtt.js"></script>
# </head>
# <body ng-controller="psPhlCtrlr" ng-init="initApp()" class="ng-scope">
#
# 	<header>
# 		<div class="container-fluid">
# 			<!-- BEGIN Header Web -->
# 			<!-- Page Header -->
# 			<div class="row page-header borderless hidden-xs">
# 				<div class="col-xs-3" style="padding: 0;">
# 					<a href="https://www.comelec.gov.ph" style="text-decoration: none;" target="_blank">
# 						<img class="img-responsive" style="max-height: 50px !important; vertical-align: middle; display: inline-block;" src="styles/images/comelec_logo.svg" alt="Commission on Elections" title="Commission on Elections">
# 						<span title="Commission on Elections" class="comelec-logo-text">COMELEC</span>
# 					</a>
# 				</div>
# 				<a href="https://www.smartmatic.com/" target="_blank">
# 					<img class="img-responsive pull-right" src="styles/images/logo_SMTT.png" alt="Smartmatic-TIM" title="Smartmatic-TIM">
# 				</a>
# 				<span class="vertical-divider pull-right"></span>
# 				<a href="https://dict.gov.ph/" target="_blank">
# 					<img class="img-responsive pull-right" src="styles/images/logo_dict.svg" style="max-height: 50px;" alt="Department of Information and Communications Technology" title="Department of Information and Communications Technology">
# 				</a>
# 			</div>
# 			<!-- Page Title -->
# 			<div class="row election-name-backgroud hidden-xs">
# 				<div class="col-xs-12 col-lg-12 no-side-padding">
# 					<div class="election-name-text smtt-h6 col-xs-12 col-sm-6 col-md-6 text-left">
# 						<span class="election-name ng-binding">09 May 2022 National and Local Elections Results</span>
# 					</div>
# 					<div class="current-date-time col-xs-12 col-sm-6 col-md-6 text-right">
# 						<span class="hidden-xs hidden-sm hidden-md ng-binding">Current date and time:</span>
# 						<span class="visible-xs-inline visible-sm-inline visible-md-inline ng-binding">Current date|time:</span>
# 						<span class="clock-time">
# 							<span class="report-date current-date ng-binding">10 May 2022 | 05:05:43 PM</span>
# 						</span>
# 					</div>
# 				</div>
# 			</div>
# 			<!-- Navigation -->
# 			<div class="row nav-buttons-section hidden-xs">
# 				<!-- ngIf: $root.currentAction != $root.TOT --><div ng-if="$root.currentAction != $root.TOT" class="tab-buttons-section col-xs-12 col-sm-7 col-md-7 ng-scope">
# 					<span>
# 						<a class="nav-button home-section-label active" ui-sref="dashboard" ui-sref-active="active" title="Dashboard" href="#/dashboard">
# 							<img class="nav-button-precincts-icon" alt="Dashboard" title="Dashboard" src="styles/images/home.png">
# 							<span class="ng-binding">Dashboard</span>
# 						</a>
# 					</span>
# 					<span>
# 						<a class="nav-button" ui-sref="er" ui-sref-active="active" title="Information based on ER" href="#/er">
# 							<img class="nav-button-precincts-icon" alt="Information based on ER" title="Information based on ER" src="styles/images/pcos.png">
# 							<span ng-bind-html="'nav.button.er.label' | translate" class="ng-binding">ER Results</span>
# 						</a>
# 					</span>
# 					<span>
# 						<a class="nav-button" ui-sref="coc" ui-sref-active="active" title="Information based on COC" href="#/coc">
# 							<img class="nav-button-boc-icon" alt="Information based on COC" title="Information based on COC" src="styles/images/CoC.png">
# 							<span ng-bind-html="'nav.button.coc.label' | translate" class="ng-binding">COC Results</span>
# 						</a>
# 					</span>
# 					<span></span>
# 				</div><!-- end ngIf: $root.currentAction != $root.TOT -->
# 				<div ng-class="{'col-sm-offset-7 col-md-offset-7': $root.currentAction == $root.TOT}" class="tab-buttons-section text-right col-xs-12 col-sm-5 col-md-5 no-side-padding" style="height: 45px">
# 					<div class="update-info text-right pull-right">
# 						<span class="report-update">
# 							<span class="report-date hidden-xs hidden-sm hidden-md ng-binding">Last update date and time: 10 May 2022 | 04:59:46 PM</span>
# 							<span class="report-date visible-xs-inline visible-sm-inline visible-md-inline ng-binding">Updated: 10 May 2022 | 04:59:46 PM</span>
# 						</span>
# 						<span class="site-information-icon pull-right">
# 							<a class="site-info-btn ng-isolate-scope ng-scope" ui-sref-val="sitemap" ui-sref-active="active" title="About This Site" ui-sref="sitemap" href="#/sitemap">
# 								<img alt="About This Site" title="About This Site" style="visibility:hidden" src="styles/images/info_icon.png">
# 							</a>
# 							<div class="site-information-content-wrapper" ng-class="{'site-information-tot': $root.currentAction === $root.TOT}">
# 								<span class="site-information-content">
# 									<p ng-bind-html="'tot.sitemap' | translate" class="ng-binding">This site is a forecast of the election results based on VCM Election Returns transmissions. These are Non-Official Election Results</p>
# 								</span>
# 							</div>
# 						</span>
# 					</div>
# 				</div>
# 			</div>
# 			<!-- END Header Web -->
#
# 			<!-- BEGIN Header Mobile -->
# 			<div class="row visible-xs">
# 				<nav class="nav-buttons-section navbar navbar-default">
# 					<div class="container-fluid">
# 						<div class="navbar-header navbar-right">
# 							<div class="col-xs-2 no-side-padding">
# 								<a class="navbar-brand" href="https://www.comelec.gov.ph" target="_blank">
# 									<img class="img-responsive pull-left" src="styles/images/comelec_logo.svg" alt="Commission on Elections" title="Commission on Elections">
# 								</a>
# 							</div>
# 							<div ng-class="{'col-xs-8': $root.currentAction === $root.TOT, 'col-xs-6': $root.currentAction !== $root.TOT }" class="no-side-padding text-center election-name col-xs-6">
# 								<span class="ng-binding">09 May 2022 National and Local Elections Results</span>
# 							</div>
# 							<div class="col-xs-2">
# 								<span class="site-information-icon">
# 								<a class="site-info-btn ng-isolate-scope ng-scope" ui-sref-val="sitemap" ui-sref-active="active" ui-sref="sitemap" href="#/sitemap">
# 									<img alt="About This Site" title="About This Site" src="styles/images/info_icon.png">
# 								</a>
# 								<div class="site-information-content-wrapper" ng-class="{'site-information-tot': $root.currentAction === $root.TOT}">
# 									<span class="site-information-content">
# 										<p ng-bind-html="'tot.sitemap' | translate" class="ng-binding">This site is a forecast of the election results based on VCM Election Returns transmissions. These are Non-Official Election Results</p>
# 									</span>
# 								</div>
# 							</span>
# 							</div>
# 							<button ng-show="$root.currentAction != $root.TOT" type="button" class="navbar-toggle collapsed" data-toggle="collapse" data-target="#bs-example-navbar-collapse-1" aria-expanded="false">
# 								<span class="sr-only">Toggle navigation</span>
# 								<span class="icon-bar"></span>
# 								<span class="icon-bar"></span>
# 								<span class="icon-bar"></span>
# 							</button>
# 						</div>
# 						<!-- Collect the nav links, forms, and other content for toggling -->
# 						<div class="collapse navbar-collapse" id="bs-example-navbar-collapse-1">
# 							<ul ng-show="$root.currentAction != $root.TOT" class="nav navbar-nav">
# 								<li>
# 									<a class="nav-button active" ui-sref="dashboard" ui-sref-active="active" href="#/dashboard">
# 										<img class="nav-button-precincts-icon" alt="Dashboard" title="Dashboard" src="styles/images/home.png">
# 										<span class="nav-button-boc-label ng-binding" ng-bind-html="'nav.button.home.label' | translate">Dashboard</span>
# 									</a>
# 								</li>
# 								<li>
# 									<a class="nav-button" ui-sref="er" ui-sref-active="active" href="#/er">
# 										<img class="nav-button-precincts-icon" alt="Information based on ER" title="Information based on ER" src="styles/images/pcos.png">
# 										<span class="nav-button-precincts-label ng-binding" ng-bind-html="'nav.button.er.label.mobile' | translate">ER</span>
# 									</a>
# 								</li>
# 								<li>
# 									<a class="nav-button" ui-sref="coc" ui-sref-active="active" href="#/coc">
# 										<img class="nav-button-boc-icon" alt="Information based on COC" title="Information based on COC" src="styles/images/CoC.png">
# 										<span class="nav-button-boc-label ng-binding" ng-bind-html="'nav.button.coc.label.mobile' | translate">COC</span>
# 									</a>
# 								</li>
# 							</ul>
# 						</div><!-- /.navbar-collapse -->
# 					</div><!-- /.container-fluid -->
# 				</nav>
# 			</div>
# 			<div class="row visible-xs">
# 				<div class="col-xs-12 col-lg-12 election-name-backgroud text-right">
# 					<div class="ng-binding">Current date|time:&nbsp;10 May 2022 | 05:05:43 PM</div>
# 					<div class="ng-binding">Updated:&nbsp;10 May 2022 | 04:59:46 PM</div>
# 				</div>
# 			</div>
# 			<!-- END Header Mobile -->
# 		</div>
# 	</header>
# 	<div class="content-wrapper">
# 		<div id="container" class="container-fluid" style="background-color: #FFF;">
# 			<!-- uiView:  --><ui-view class="ng-scope"><div class="inside-full-height main-wrapper dashboard ng-scope">
#     <div class="loading ng-hide" data-loading=""></div>
#     <div ng-show="!dashboard" class="ng-binding ng-hide">Results for Election have not been published yet</div>
#     <div ng-show="dashboard" class="row">
#         <br class="hidden-xs hidden-sm">
#         <div class="col-xs-12 col-sm-12 no-side-padding">
#             <div class="col-xs-12 col-sm-12 region-contest-header ng-binding">Election Returns (ERs) Received</div>
#             <div class="col-xs-12 col-sm-12 no-side-padding">
#                 <!-- ngRepeat: table in dashboard.er --><div class="col-xs-12 col-sm-4 col-md-4 col-lg-3 ng-scope" ng-repeat="table in dashboard.er">
#                     <dashboard-tbl data="table" class="ng-isolate-scope"><div class="smtt-dashboard-table">
#     <div class="smtt-header ng-binding">Local ERs</div>
#     <!-- ngRepeat: row in table.rows --><div class="smtt-dashboard-row ng-scope" ng-repeat="row in table.rows">
#         <div class="ng-binding">ERs Expected</div>
#         <div class="ng-binding">106,174</div>
#     </div><!-- end ngRepeat: row in table.rows --><div class="smtt-dashboard-row ng-scope" ng-repeat="row in table.rows">
#         <div class="ng-binding">ERs Received</div>
#         <div class="ng-binding">104,767</div>
#     </div><!-- end ngRepeat: row in table.rows -->
#     <div>
#     </div>
#     <div class="progressbar">
#         <div class="text-left candidate-result-bottom">
#             <!-- Progress bar -->
#             <div class="progress" style="margin-bottom: 0px;">
#                 <div class="progress-bar ng-binding" role="progressbar" aria-valuenow="98.67" aria-valuemin="0" aria-valuemax="100" ng-style="{'width':table.progress+'%'}" style="width: 98.67%;">
#                     98.67%
#                 </div>
#             </div>
#
#         </div>
#     </div>
# </div>
# </dashboard-tbl>
#                 </div><!-- end ngRepeat: table in dashboard.er --><div class="col-xs-12 col-sm-4 col-md-4 col-lg-3 ng-scope" ng-repeat="table in dashboard.er">
#                     <dashboard-tbl data="table" class="ng-isolate-scope"><div class="smtt-dashboard-table">
#     <div class="smtt-header ng-binding">Overseas ERs</div>
#     <!-- ngRepeat: row in table.rows --><div class="smtt-dashboard-row ng-scope" ng-repeat="row in table.rows">
#         <div class="ng-binding">ERs Expected</div>
#         <div class="ng-binding">1,406</div>
#     </div><!-- end ngRepeat: row in table.rows --><div class="smtt-dashboard-row ng-scope" ng-repeat="row in table.rows">
#         <div class="ng-binding">ERs Received</div>
#         <div class="ng-binding">851</div>
#     </div><!-- end ngRepeat: row in table.rows -->
#     <div>
#     </div>
#     <div class="progressbar">
#         <div class="text-left candidate-result-bottom">
#             <!-- Progress bar -->
#             <div class="progress" style="margin-bottom: 0px;">
#                 <div class="progress-bar ng-binding" role="progressbar" aria-valuenow="60.52" aria-valuemin="0" aria-valuemax="100" ng-style="{'width':table.progress+'%'}" style="width: 60.52%;">
#                     60.52%
#                 </div>
#             </div>
#
#         </div>
#     </div>
# </div>
# </dashboard-tbl>
#                 </div><!-- end ngRepeat: table in dashboard.er -->
#             </div>
#         </div>
#         <br class="hidden-xs hidden-sm">
#         <div class="col-xs-12 col-sm-12 no-side-padding">
#             <div class="col-xs-12 col-sm-12 region-contest-header ng-binding">Certificates of Canvass (COCs) Received</div>
#             <div class="col-xs-12 col-sm-12 no-side-padding">
#                 <!-- ngRepeat: table in dashboard.coc --><div class="col-xs-12 col-sm-4 col-md-4 col-lg-3 ng-scope" ng-repeat="table in dashboard.coc">
#                     <dashboard-tbl data="table" class="ng-isolate-scope"><div class="smtt-dashboard-table">
#     <div class="smtt-header ng-binding">National COCs</div>
#     <!-- ngRepeat: row in table.rows --><div class="smtt-dashboard-row ng-scope" ng-repeat="row in table.rows">
#         <div class="ng-binding">COCs Expected</div>
#         <div class="ng-binding">2</div>
#     </div><!-- end ngRepeat: row in table.rows --><div class="smtt-dashboard-row ng-scope" ng-repeat="row in table.rows">
#         <div class="ng-binding">COCs Received</div>
#         <div class="ng-binding">0</div>
#     </div><!-- end ngRepeat: row in table.rows -->
#     <div>
#     </div>
#     <div class="progressbar">
#         <div class="text-left candidate-result-bottom">
#             <!-- Progress bar -->
#             <div class="progress" style="margin-bottom: 0px;">
#                 <div class="progress-bar ng-binding" role="progressbar" aria-valuenow="0.00" aria-valuemin="0" aria-valuemax="100" ng-style="{'width':table.progress+'%'}" style="width: 0%;">
#                     0.00%
#                 </div>
#             </div>
#
#         </div>
#     </div>
# </div>
# </dashboard-tbl>
#                 </div><!-- end ngRepeat: table in dashboard.coc --><div class="col-xs-12 col-sm-4 col-md-4 col-lg-3 ng-scope" ng-repeat="table in dashboard.coc">
#                     <dashboard-tbl data="table" class="ng-isolate-scope"><div class="smtt-dashboard-table">
#     <div class="smtt-header ng-binding">Provincial/District COCs</div>
#     <!-- ngRepeat: row in table.rows --><div class="smtt-dashboard-row ng-scope" ng-repeat="row in table.rows">
#         <div class="ng-binding">COCs Expected</div>
#         <div class="ng-binding">83</div>
#     </div><!-- end ngRepeat: row in table.rows --><div class="smtt-dashboard-row ng-scope" ng-repeat="row in table.rows">
#         <div class="ng-binding">COCs Received</div>
#         <div class="ng-binding">28</div>
#     </div><!-- end ngRepeat: row in table.rows -->
#     <div>
#     </div>
#     <div class="progressbar">
#         <div class="text-left candidate-result-bottom">
#             <!-- Progress bar -->
#             <div class="progress" style="margin-bottom: 0px;">
#                 <div class="progress-bar ng-binding" role="progressbar" aria-valuenow="33.73" aria-valuemin="0" aria-valuemax="100" ng-style="{'width':table.progress+'%'}" style="width: 33.73%;">
#                     33.73%
#                 </div>
#             </div>
#
#         </div>
#     </div>
# </div>
# </dashboard-tbl>
#                 </div><!-- end ngRepeat: table in dashboard.coc --><div class="col-xs-12 col-sm-4 col-md-4 col-lg-3 ng-scope" ng-repeat="table in dashboard.coc">
#                     <dashboard-tbl data="table" class="ng-isolate-scope"><div class="smtt-dashboard-table">
#     <div class="smtt-header ng-binding">City/Municipal COCs</div>
#     <!-- ngRepeat: row in table.rows --><div class="smtt-dashboard-row ng-scope" ng-repeat="row in table.rows">
#         <div class="ng-binding">COCs Expected</div>
#         <div class="ng-binding">1,633</div>
#     </div><!-- end ngRepeat: row in table.rows --><div class="smtt-dashboard-row ng-scope" ng-repeat="row in table.rows">
#         <div class="ng-binding">COCs Received</div>
#         <div class="ng-binding">1,466</div>
#     </div><!-- end ngRepeat: row in table.rows -->
#     <div>
#     </div>
#     <div class="progressbar">
#         <div class="text-left candidate-result-bottom">
#             <!-- Progress bar -->
#             <div class="progress" style="margin-bottom: 0px;">
#                 <div class="progress-bar ng-binding" role="progressbar" aria-valuenow="89.77" aria-valuemin="0" aria-valuemax="100" ng-style="{'width':table.progress+'%'}" style="width: 89.77%;">
#                     89.77%
#                 </div>
#             </div>
#
#         </div>
#     </div>
# </div>
# </dashboard-tbl>
#                 </div><!-- end ngRepeat: table in dashboard.coc --><div class="col-xs-12 col-sm-4 col-md-4 col-lg-3 ng-scope" ng-repeat="table in dashboard.coc">
#                     <dashboard-tbl data="table" class="ng-isolate-scope"><div class="smtt-dashboard-table">
#     <div class="smtt-header ng-binding">Overseas COCs</div>
#     <!-- ngRepeat: row in table.rows --><div class="smtt-dashboard-row ng-scope" ng-repeat="row in table.rows">
#         <div class="ng-binding">COCs Expected</div>
#         <div class="ng-binding">26</div>
#     </div><!-- end ngRepeat: row in table.rows --><div class="smtt-dashboard-row ng-scope" ng-repeat="row in table.rows">
#         <div class="ng-binding">COCs Received</div>
#         <div class="ng-binding">10</div>
#     </div><!-- end ngRepeat: row in table.rows -->
#     <div>
#     </div>
#     <div class="progressbar">
#         <div class="text-left candidate-result-bottom">
#             <!-- Progress bar -->
#             <div class="progress" style="margin-bottom: 0px;">
#                 <div class="progress-bar ng-binding" role="progressbar" aria-valuenow="38.46" aria-valuemin="0" aria-valuemax="100" ng-style="{'width':table.progress+'%'}" style="width: 38.46%;">
#                     38.46%
#                 </div>
#             </div>
#
#         </div>
#     </div>
# </div>
# </dashboard-tbl>
#                 </div><!-- end ngRepeat: table in dashboard.coc -->
#             </div>
#         </div>
#     </div>
# </div>
# </ui-view>
# 		</div>
# 	</div>
# 	<footer class="footer navbar-fixed-bottom">
# 		<div class="container-fluid footer col-xs-12 text-right hidden-xs">
# 			<span class="ng-binding">Version: 7.5.1</span>
# 		</div>
# 		<div class="col-xs-12 text-center visible-xs">
# 			<img class="img-footer" src="styles/images/logo_smtt_dark_gray.png" alt="Smartmatic-TIM" title="Smartmatic-TIM">
# 			<span class="footer-gray ng-binding">Copyright © Smartmatic 2022</span>
# 		</div>
# 	</footer>
#
#
# </body></html>
